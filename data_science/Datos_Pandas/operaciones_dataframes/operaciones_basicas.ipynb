# %% [markdown]
# ## Operaciones básicas

# %%
import pandas as pd
import numpy as np

from pathlib import Path

data_path = Path('../estructura_datos/data')
data = pd.read_csv(data_path/'house.csv')
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data.shape
# Out:
# (4600, 18)

# %%
data.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
data.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data['bedrooms'].value_counts(dropna=False, normalize=True)
# Out:
# bedrooms
# 3.0    0.441739
# 4.0    0.332826
# 2.0    0.123043
# 5.0    0.076739
# 6.0    0.013261
# 1.0    0.008261
# 7.0    0.003043
# 8.0    0.000435
# 0.0    0.000435
# 9.0    0.000217
# Name: proportion, dtype: float64

# %% [markdown]
# ## qcut y cut

# %%
pd.qcut(data['price'], q=5)
# Out:
# 0       (297785.714, 405000.0]
# 1       (718600.0, 26590000.0]
# 2       (297785.714, 405000.0]
# 3         (405000.0, 530000.0]
# 4         (530000.0, 718600.0]
#                  ...
# 4595    (297785.714, 405000.0]
# 4596      (530000.0, 718600.0]
# 4597      (405000.0, 530000.0]
# 4598      (-0.001, 297785.714]
# 4599      (-0.001, 297785.714]
# Name: price, Length: 4600, dtype: category
# Categories (5, interval[float64, right]): [(-0.001, 297785.714] < (297785.714, 405000.0] < (405000.0, 530000.0] < (530000.0, 718600.0] < (718600.0, 26590000.0]]

# %%
pd.qcut(data['price'], q=5).value_counts()
# Out:
# price
# (297785.714, 405000.0]    929
# (-0.001, 297785.714]      920
# (405000.0, 530000.0]      920
# (718600.0, 26590000.0]    920
# (530000.0, 718600.0]      911
# Name: count, dtype: int64

# %%
pd.cut(data['bedrooms'], bins=2)
# Out:
# 0       (-0.009, 4.5]
# 1          (4.5, 9.0]
# 2       (-0.009, 4.5]
# 3       (-0.009, 4.5]
# 4       (-0.009, 4.5]
#             ...
# 4595    (-0.009, 4.5]
# 4596    (-0.009, 4.5]
# 4597    (-0.009, 4.5]
# 4598    (-0.009, 4.5]
# 4599    (-0.009, 4.5]
# Name: bedrooms, Length: 4600, dtype: category
# Categories (2, interval[float64, right]): [(-0.009, 4.5] < (4.5, 9.0]]

# %%
pd.cut(data['bedrooms'], bins=2).value_counts()
# Out:
# bedrooms
# (-0.009, 4.5]    4169
# (4.5, 9.0]        431
# Name: count, dtype: int64

# %%
pd.cut(data['bedrooms'], bins=[-1,3,8,10], labels=['menos de 3', 'entre 3 y 8', 'entre 8 y 10'])
# Out:
# 0        menos de 3
# 1       entre 3 y 8
# 2        menos de 3
# 3        menos de 3
# 4       entre 3 y 8
#            ...
# 4595     menos de 3
# 4596     menos de 3
# 4597     menos de 3
# 4598    entre 3 y 8
# 4599     menos de 3
# Name: bedrooms, Length: 4600, dtype: category
# Categories (3, object): ['menos de 3' < 'entre 3 y 8' < 'entre 8 y 10']

# %%
data.sort_values(by='bedrooms', ascending=True, inplace=False)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 3209  2014-06-24 00:00:00  1295648.0       0.0       0.00         4810
# 2365  2014-06-12 00:00:00  1095000.0       0.0       0.00         3064
# 4556  2014-06-27 00:00:00   167500.0       1.0       1.00          690
# 784   2014-05-16 00:00:00   350000.0       1.0       1.00          700
# 3633  2014-06-30 00:00:00   410000.0       1.0       1.50         1010
# ...                   ...        ...       ...        ...          ...
# 4243  2014-07-09 00:00:00   599000.0       7.0       2.50         2580
# 1455  2014-05-28 00:00:00   999000.0       7.0       4.00         3150
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 241   2014-05-07 00:00:00   599999.0       9.0       4.50         3830
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %% [markdown]
# ## Copy

# %%
_ = data.query('bedrooms == 0')
_
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 2365  2014-06-12 00:00:00  1095000.0       0.0        0.0         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0        0.0         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2365      4764     3.5           0     2          3        3064
# 3209     28008     2.0           0     0          3        4810
#
#       sqft_basement  yr_built  yr_renovated            street     city  \
# 2365              0      1990          2009     814 E Howe St  Seattle
# 3209              0      1990          2009  20418 NE 64th Pl  Redmond
#
#       statezip country
# 2365  WA 98102     USA
# 3209  WA 98053     USA

# %%
d = _.copy(deep=False)

# %%
_.iat[0,2] = 10
_
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 2365  2014-06-12 00:00:00  1095000.0      10.0        0.0         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0        0.0         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2365      4764     3.5           0     2          3        3064
# 3209     28008     2.0           0     0          3        4810
#
#       sqft_basement  yr_built  yr_renovated            street     city  \
# 2365              0      1990          2009     814 E Howe St  Seattle
# 3209              0      1990          2009  20418 NE 64th Pl  Redmond
#
#       statezip country
# 2365  WA 98102     USA
# 3209  WA 98053     USA

# %%
d
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 2365  2014-06-12 00:00:00  1095000.0      10.0        0.0         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0        0.0         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2365      4764     3.5           0     2          3        3064
# 3209     28008     2.0           0     0          3        4810
#
#       sqft_basement  yr_built  yr_renovated            street     city  \
# 2365              0      1990          2009     814 E Howe St  Seattle
# 3209              0      1990          2009  20418 NE 64th Pl  Redmond
#
#       statezip country
# 2365  WA 98102     USA
# 3209  WA 98053     USA
